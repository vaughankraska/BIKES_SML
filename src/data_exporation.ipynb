# %%
# data_exploration.ipynb

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
data = pd.read_csv('./store/training_data.csv')

# Function to plot a feature against bike demand
def plot_feature_vs_demand(data, feature, title):
    plt.figure(figsize=(12, 6))
    sns.countplot(x=feature, hue='increase_stock', data=data)
    plt.title(title)
    plt.xticks(rotation=45)
    plt.show()

# %%
# basic data exploration
data.head()
# Out:
#    hour_of_day  day_of_week  month  holiday  weekday  summertime  temp   dew  \
# 0            5            5      1        0        0           0  -7.2 -15.0
# 1           21            4      1        0        1           0  -1.3 -12.8
# 2           21            3      8        0        1           1  26.9  21.8
# 3            1            6      1        0        0           0   3.1  -4.0
# 4           17            0      3        0        1           0  11.7 -11.4
#
#    humidity  precip  snow  snowdepth  windspeed  cloudcover  visibility  \
# 0     53.68     0.0     0        0.0       16.3        31.6        16.0
# 1     40.97     0.0     0        0.0       23.9        85.7        16.0
# 2     73.39     0.0     0        0.0        0.0        81.1        16.0
# 3     59.74     0.0     0        0.0       19.2         0.0        16.0
# 4     18.71     0.0     0        0.0       10.5        44.6        16.0
#
#     increase_stock
# 0  low_bike_demand
# 1  low_bike_demand
# 2  low_bike_demand
# 3  low_bike_demand
# 4  low_bike_demand

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1600 entries, 0 to 1599
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   hour_of_day     1600 non-null   int64
#  1   day_of_week     1600 non-null   int64
#  2   month           1600 non-null   int64
#  3   holiday         1600 non-null   int64
#  4   weekday         1600 non-null   int64
#  5   summertime      1600 non-null   int64
#  6   temp            1600 non-null   float64
#  7   dew             1600 non-null   float64
#  8   humidity        1600 non-null   float64
#  9   precip          1600 non-null   float64
#  10  snow            1600 non-null   int64
#  11  snowdepth       1600 non-null   float64
#  12  windspeed       1600 non-null   float64
#  13  cloudcover      1600 non-null   float64
#  14  visibility      1600 non-null   float64
#  15  increase_stock  1600 non-null   object
# dtypes: float64(8), int64(7), object(1)
# memory usage: 200.1+ KB

# %%
data
# Out:
#       hour_of_day  day_of_week  month  holiday  weekday  summertime  temp  \
# 0               5            5      1        0        0           0  -7.2
# 1              21            4      1        0        1           0  -1.3
# 2              21            3      8        0        1           1  26.9
# 3               1            6      1        0        0           0   3.1
# 4              17            0      3        0        1           0  11.7
# ...           ...          ...    ...      ...      ...         ...   ...
# 1595            3            5      6        0        0           1  21.5
# 1596           14            0      6        0        1           1  23.2
# 1597           13            0      3        0        1           1  13.9
# 1598           14            5      3        0        0           1  11.7
# 1599           22            6      2        0        0           0   4.2
#
#        dew  humidity  precip  snow  snowdepth  windspeed  cloudcover  \
# 0    -15.0     53.68   0.000     0        0.0       16.3        31.6
# 1    -12.8     40.97   0.000     0        0.0       23.9        85.7
# 2     21.8     73.39   0.000     0        0.0        0.0        81.1
# 3     -4.0     59.74   0.000     0        0.0       19.2         0.0
# 4    -11.4     18.71   0.000     0        0.0       10.5        44.6
# ...    ...       ...     ...   ...        ...        ...         ...
# 1595  19.4     87.68   0.000     0        0.0       10.6        24.4
# 1596  20.1     82.43   2.217     0        0.0        9.8        92.1
# 1597  -2.2     32.93   0.000     0        2.0       18.2        79.3
# 1598  -9.3     22.09   0.000     0        0.0        5.8        24.4
# 1599   1.7     84.11   1.081     0        0.0       21.9        97.4
#
#       visibility    increase_stock
# 0           16.0   low_bike_demand
# 1           16.0   low_bike_demand
# 2           16.0   low_bike_demand
# 3           16.0   low_bike_demand
# 4           16.0   low_bike_demand
# ...          ...               ...
# 1595        16.0   low_bike_demand
# 1596        10.4   low_bike_demand
# 1597        16.0   low_bike_demand
# 1598        16.0  high_bike_demand
# 1599        16.0   low_bike_demand
#
# [1600 rows x 16 columns]

# %%
data.shape
# Out:
# (1600, 16)

# %%
data.describe()
# Out:
#        hour_of_day  day_of_week        month      holiday      weekday  \
# count   1600.00000  1600.000000  1600.000000  1600.000000  1600.000000
# mean      11.37125     3.022500     6.468750     0.033125     0.710000
# std        6.94837     2.012965     3.454741     0.179019     0.453904
# min        0.00000     0.000000     1.000000     0.000000     0.000000
# 25%        5.00000     1.000000     3.000000     0.000000     0.000000
# 50%       12.00000     3.000000     6.000000     0.000000     1.000000
# 75%       17.00000     5.000000     9.000000     0.000000     1.000000
# max       23.00000     6.000000    12.000000     1.000000     1.000000
#
#        summertime         temp          dew     humidity       precip    snow  \
# count  1600.00000  1600.000000  1600.000000  1600.000000  1600.000000  1600.0
# mean      0.64375    15.210313     7.750750    63.927844     0.122042     0.0
# std       0.47904     9.264785    10.026459    19.079419     0.920600     0.0
# min       0.00000    -9.100000   -18.400000    15.850000     0.000000     0.0
# 25%       0.00000     7.700000    -0.800000    47.845000     0.000000     0.0
# 50%       1.00000    15.500000     8.300000    65.175000     0.000000     0.0
# 75%       1.00000    23.200000    16.800000    79.955000     0.000000     0.0
# max       1.00000    35.600000    24.300000    99.890000    25.871000     0.0
#
#          snowdepth    windspeed   cloudcover   visibility
# count  1600.000000  1600.000000  1600.000000  1600.000000
# mean      0.042713    13.082500    64.322375    15.344125
# std       0.421198     7.756652    32.748869     2.323737
# min       0.000000     0.000000     0.000000     0.100000
# 25%       0.000000     7.500000    28.800000    16.000000
# 50%       0.000000    12.300000    79.300000    16.000000
# 75%       0.000000    17.600000    92.800000    16.000000
# max       6.710000    43.800000   100.000000    16.000000

# %%
# exploratory plots
_ = data.hist()

# %%
# What percentage of the labels claim "high_bike_demand"?
print(data["increase_stock"].value_counts())
percentage_high_bike_demand = np.sum([1 if row == "high_bike_demand" else 0 for row in data["increase_stock"]]) / data.shape[0]
print(f"percentage: {percentage_high_bike_demand}")
# Out:
# increase_stock
# low_bike_demand     1312
# high_bike_demand     288
# Name: count, dtype: int64
# percentage: 0.18

# %%
# Percentage of high/low bike demand per month
data_time = data[["month", "hour_of_day","day_of_week","increase_stock"]]
df_month = data_time.groupby(['month', "increase_stock"]).count().reset_index().drop(columns =["day_of_week"])
df_help = data_time["month"].value_counts().reset_index()
df_month = pd.merge(df_month,df_help,left_on= df_month["month"], right_on= df_help["month"], how = "inner").drop(columns =["month_y","key_0"])
df_month = df_month.rename(columns={"hour_of_day": "count_stock","count":"count_month","month_x":"month"})
df_month["perc_stock"] = df_month["count_stock"] / df_month["count_month"]
_ = sns.barplot(data = df_month, x="month",y="perc_stock", hue = "increase_stock")
# Out:
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
data[["hour_of_day","increase_stock","month"]].groupby(by=["hour_of_day","increase_stock"]).count()
# Out:
#                               month
# hour_of_day increase_stock
# 0           low_bike_demand      84
# 1           low_bike_demand      67
# 2           low_bike_demand      53
# 3           low_bike_demand      69
# 4           low_bike_demand      69
# 5           low_bike_demand      67
# 6           low_bike_demand      62
# 7           high_bike_demand      2
#             low_bike_demand      75
# 8           high_bike_demand     13
#             low_bike_demand      53
# 9           high_bike_demand     11
#             low_bike_demand      52
# 10          high_bike_demand     10
#             low_bike_demand      53
# 11          high_bike_demand     13
#             low_bike_demand      45
# 12          high_bike_demand     20
#             low_bike_demand      46
# 13          high_bike_demand     17
#             low_bike_demand      61
# 14          high_bike_demand     18
#             low_bike_demand      52
# 15          high_bike_demand     33
#             low_bike_demand      31
# 16          high_bike_demand     39
#             low_bike_demand      44
# 17          high_bike_demand     43
#             low_bike_demand      29
# 18          high_bike_demand     39
#             low_bike_demand      14
# 19          high_bike_demand     25
#             low_bike_demand      32
# 20          high_bike_demand      4
#             low_bike_demand      51
# 21          low_bike_demand      71
# 22          high_bike_demand      1
#             low_bike_demand      55
# 23          low_bike_demand      77

# %%
sns.countplot(data = data, x="summertime", hue = "increase_stock")
# Out:
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='summertime', ylabel='count'>

# %%
# Percentage of high/low bike demand day of the week
df_weekday = data_time.groupby(['day_of_week', "increase_stock"]).count().reset_index().drop(columns =["month"])
df_help = data_time["day_of_week"].value_counts().reset_index()
df_weekday = pd.merge(df_weekday,df_help,left_on= df_weekday["day_of_week"], right_on= df_help["day_of_week"], how = "inner").drop(columns =["day_of_week_y","key_0"])
df_weekday = df_weekday.rename(columns={"hour_of_day": "count_stock","count":"count_weekday","day_of_week_x":"day_of_week"})
df_weekday["perc_stock"] = df_weekday["count_stock"] / df_weekday["count_weekday"]
_ = sns.barplot(data = df_weekday, x="day_of_week",y="perc_stock", hue = "increase_stock")
# Out:
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
# Is there any difference between weekdays and holidays?
plot_feature_vs_demand(data, 'weekday', 'Bike Demand on Weekdays vs Weekends')
plot_feature_vs_demand(data, 'holiday', 'Bike Demand on Holidays vs Regular Days')
# Out:
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
# Holiday exploration
bar_day_of_week_data = data[['day_of_week', 'increase_stock']].groupby('day_of_week')['increase_stock'].value_counts(normalize=True).reset_index(name='proportion')
sns.barplot(data=bar_day_of_week_data, x='day_of_week', y='proportion',
            hue='increase_stock', palette='viridis')
plt.xlabel('Holiday (1=True, 0=False)')
plt.ylabel('Percentage of Category')
# Out:
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# Text(0, 0.5, 'Percentage of Category')

# %%
bar_holiday = data[['holiday','increase_stock']].groupby('holiday')['increase_stock'].value_counts(normalize=True).reset_index(name='proportion')
sns.barplot(data=bar_holiday, x='holiday', y='proportion', hue='increase_stock', palette='viridis')
plt.xlabel('Holiday (1=True, 0=False)')
plt.ylabel('Percentage of Category')
# Out:
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# Text(0, 0.5, 'Percentage of Category')

# %%
# Percentage of high/low bike demand hour of the day
df_hour = data_time.groupby(['hour_of_day', "increase_stock"]).count().reset_index().drop(columns =["month"])
df_help = data_time["hour_of_day"].value_counts().reset_index()
df_hour = pd.merge(df_hour,df_help,left_on= df_hour["hour_of_day"], right_on= df_help["hour_of_day"], how = "inner").drop(columns =["hour_of_day_y","key_0"])
df_hour = df_hour.rename(columns={"day_of_week": "count_stock","count":"count_hour","hour_of_day_x":"hour_of_day"})
df_hour["perc_stock"] = df_hour["count_stock"] / df_hour["count_hour"]
_ = sns.barplot(data = df_hour, x="hour_of_day",y="perc_stock", hue = "increase_stock")
# Out:
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
# Day of week exploration
df_hourday = data_time.groupby(['day_of_week',"hour_of_day","increase_stock"]).count().reset_index()
df_hourday = df_hourday.rename(columns={"month":"count"})

# %%
sns.barplot(data = df_hourday[df_hourday["day_of_week"] ==0], x="hour_of_day",y="count", hue = "increase_stock")
# Out:
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='hour_of_day', ylabel='count'>

# %%
sns.barplot(data = df_hourday[df_hourday["day_of_week"] ==1], x="hour_of_day",y="count", hue = "increase_stock")
# Out:
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='hour_of_day', ylabel='count'>

# %%
sns.barplot(data = df_hourday[df_hourday["day_of_week"] ==2], x="hour_of_day",y="count", hue = "increase_stock")
# Out:
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='hour_of_day', ylabel='count'>

# %%
sns.barplot(data = df_hourday[df_hourday["day_of_week"] ==3], x="hour_of_day",y="count", hue = "increase_stock")
# Out:
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='hour_of_day', ylabel='count'>

# %%
sns.barplot(data = df_hourday[df_hourday["day_of_week"] ==4], x="hour_of_day",y="count", hue = "increase_stock")
# Out:
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='hour_of_day', ylabel='count'>

# %%
sns.barplot(data = df_hourday[df_hourday["day_of_week"] ==5], x="hour_of_day",y="count", hue = "increase_stock")
# Out:
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='hour_of_day', ylabel='count'>

# %%
sns.barplot(data = df_hourday[df_hourday["day_of_week"] ==6], x="hour_of_day",y="count", hue = "increase_stock")
# Out:
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='hour_of_day', ylabel='count'>

# %%
# Is there any trend depending on the weather? Rainy days, snowy days, etc.
plot_feature_vs_demand(data, 'temp', 'Bike Demand by Temperature')
plot_feature_vs_demand(data, 'precip', 'Bike Demand by Precipitation')
plot_feature_vs_demand(data, 'snow', 'Bike Demand by Snow')
plot_feature_vs_demand(data, 'humidity', 'Bike Demand by Humidity')
plot_feature_vs_demand(data, 'cloudcover', 'Bike Demand by Cloud Cover')
# Out:
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
# Load new data set with new features
data_copy = pd.read_csv('./store/data_exploration.csv',index_col=[0])
data_copy["increase_stock"].replace(('high_bike_demand', 'low_bike_demand'), (1, 0), inplace=True)

# %%
data_copy.iloc[:4]
# Out:
#    hour_of_day  day_of_week  month  holiday  weekday  summertime  temp   dew  \
# 0            5            5      1        0        0           0  -7.2 -15.0
# 1           21            4      1        0        1           0  -1.3 -12.8
# 2           21            3      8        0        1           1  26.9  21.8
# 3            1            6      1        0        0           0   3.1  -4.0
#
#    humidity  precip  snowdepth  windspeed  cloudcover  visibility  \
# 0     53.68     0.0        0.0       16.3        31.6        16.0
# 1     40.97     0.0        0.0       23.9        85.7        16.0
# 2     73.39     0.0        0.0        0.0        81.1        16.0
# 3     59.74     0.0        0.0       19.2         0.0        16.0
#
#    increase_stock  daytime  rushhour  weather_score  weather_score_daytime
# 0               0        0         0      -0.141957                   -0.0
# 1               0        0         0       0.075260                    0.0
# 2               0        0         0       0.261261                    0.0
# 3               0        0         0      -0.050008                   -0.0

# %%
data_copy["increase_stock"].replace(('high_bike_demand', 'low_bike_demand'), (1, 0), inplace=True)
data_copy.corr()
# Out:
#                        hour_of_day  day_of_week     month   holiday   weekday  \
# hour_of_day               1.000000    -0.005963 -0.016503  0.012732 -0.028899
# day_of_week              -0.005963     1.000000 -0.032363 -0.128759 -0.786150
# month                    -0.016503    -0.032363  1.000000 -0.016021  0.049254
# holiday                   0.012732    -0.128759 -0.016021  1.000000  0.118294
# weekday                  -0.028899    -0.786150  0.049254  0.118294  1.000000
# summertime                0.005376     0.010263  0.046929 -0.132132 -0.023872
# temp                      0.157994     0.003727  0.207436 -0.055069  0.007433
# dew                      -0.023067     0.014271  0.272927 -0.060239  0.009804
# humidity                 -0.325988     0.016976  0.173159 -0.017260  0.016758
# precip                   -0.008747    -0.011158  0.004232 -0.005564  0.029214
# snowdepth                -0.006031    -0.045930 -0.127751 -0.013385  0.024333
# windspeed                 0.161313     0.033726 -0.207056 -0.019129 -0.024126
# cloudcover                0.002672     0.043354 -0.083544  0.014093  0.008788
# visibility                0.012115    -0.018810  0.028287 -0.028171 -0.011815
# increase_stock            0.240544     0.083688  0.037212 -0.004909 -0.116446
# daytime                   0.242792     0.023960 -0.015555  0.015294 -0.001936
# rushhour                  0.402482    -0.000309 -0.003680  0.026803 -0.008827
# weather_score             0.348048    -0.011015 -0.012658 -0.012785  0.007414
# weather_score_daytime     0.289222    -0.003827 -0.021195 -0.001526  0.010801
#
#                        summertime      temp       dew  humidity    precip  \
# hour_of_day              0.005376  0.157994 -0.023067 -0.325988 -0.008747
# day_of_week              0.010263  0.003727  0.014271  0.016976 -0.011158
# month                    0.046929  0.207436  0.272927  0.173159  0.004232
# holiday                 -0.132132 -0.055069 -0.060239 -0.017260 -0.005564
# weekday                 -0.023872  0.007433  0.009804  0.016758  0.029214
# summertime               1.000000  0.707637  0.645944  0.064755  0.012930
# temp                     0.707637  1.000000  0.871536  0.008306 -0.003313
# dew                      0.645944  0.871536  1.000000  0.489590  0.071566
# humidity                 0.064755  0.008306  0.489590  1.000000  0.174768
# precip                   0.012930 -0.003313  0.071566  0.174768  1.000000
# snowdepth               -0.127991 -0.153692 -0.119660  0.033598  0.011242
# windspeed               -0.028827 -0.037656 -0.190793 -0.340557  0.060778
# cloudcover              -0.022964 -0.012421  0.146844  0.331976  0.126660
# visibility               0.068963  0.119909 -0.050474 -0.376796 -0.455058
# increase_stock           0.216052  0.336981  0.132663 -0.308726 -0.059304
# daytime                 -0.010645  0.141392 -0.018985 -0.275595  0.010033
# rushhour                 0.029729  0.204051  0.000957 -0.333844  0.002245
# weather_score            0.450464  0.702599  0.276600 -0.643688 -0.123647
# weather_score_daytime    0.264502  0.503076  0.121739 -0.595148 -0.080598
#
#                        snowdepth  windspeed  cloudcover  visibility  \
# hour_of_day            -0.006031   0.161313    0.002672    0.012115
# day_of_week            -0.045930   0.033726    0.043354   -0.018810
# month                  -0.127751  -0.207056   -0.083544    0.028287
# holiday                -0.013385  -0.019129    0.014093   -0.028171
# weekday                 0.024333  -0.024126    0.008788   -0.011815
# summertime             -0.127991  -0.028827   -0.022964    0.068963
# temp                   -0.153692  -0.037656   -0.012421    0.119909
# dew                    -0.119660  -0.190793    0.146844   -0.050474
# humidity                0.033598  -0.340557    0.331976   -0.376796
# precip                  0.011242   0.060778    0.126660   -0.455058
# snowdepth               1.000000   0.126995    0.062844   -0.159623
# windspeed               0.126995   1.000000    0.087295    0.023009
# cloudcover              0.062844   0.087295    1.000000   -0.251001
# visibility             -0.159623   0.023009   -0.251001    1.000000
# increase_stock         -0.047526   0.096011   -0.045534    0.113443
# daytime                 0.018000   0.206523    0.031580   -0.014092
# rushhour               -0.037800   0.167772    0.007201    0.044857
# weather_score          -0.099091   0.200182   -0.094937    0.236527
# weather_score_daytime  -0.069243   0.225956   -0.109951    0.168817
#
#                        increase_stock   daytime  rushhour  weather_score  \
# hour_of_day                  0.240544  0.242792  0.402482       0.348048
# day_of_week                  0.083688  0.023960 -0.000309      -0.011015
# month                        0.037212 -0.015555 -0.003680      -0.012658
# holiday                     -0.004909  0.015294  0.026803      -0.012785
# weekday                     -0.116446 -0.001936 -0.008827       0.007414
# summertime                   0.216052 -0.010645  0.029729       0.450464
# temp                         0.336981  0.141392  0.204051       0.702599
# dew                          0.132663 -0.018985  0.000957       0.276600
# humidity                    -0.308726 -0.275595 -0.333844      -0.643688
# precip                      -0.059304  0.010033  0.002245      -0.123647
# snowdepth                   -0.047526  0.018000 -0.037800      -0.099091
# windspeed                    0.096011  0.206523  0.167772       0.200182
# cloudcover                  -0.045534  0.031580  0.007201      -0.094937
# visibility                   0.113443 -0.014092  0.044857       0.236527
# increase_stock               1.000000  0.412841  0.482137       0.479621
# daytime                      0.412841  1.000000  0.466044       0.321457
# rushhour                     0.482137  0.466044  1.000000       0.419673
# weather_score                0.479621  0.321457  0.419673       1.000000
# weather_score_daytime        0.579521  0.616051  0.549650       0.835806
#
#                        weather_score_daytime
# hour_of_day                         0.289222
# day_of_week                        -0.003827
# month                              -0.021195
# holiday                            -0.001526
# weekday                             0.010801
# summertime                          0.264502
# temp                                0.503076
# dew                                 0.121739
# humidity                           -0.595148
# precip                             -0.080598
# snowdepth                          -0.069243
# windspeed                           0.225956
# cloudcover                         -0.109951
# visibility                          0.168817
# increase_stock                      0.579521
# daytime                             0.616051
# rushhour                            0.549650
# weather_score                       0.835806
# weather_score_daytime               1.000000

# %%
def get_top_correlations_blog(df, threshold=0.4):
    """
    df: the dataframe to get correlations from
    threshold: the maximum and minimum value to include for correlations. For eg, if this is 0.4, only pairs haveing a correlation coefficient greater than 0.4 or less than -0.4 will be included in the results. 
    """
    orig_corr = df.corr()
    c = orig_corr.abs()

    so = c.unstack()
    
    print("|    Variable 1    |    Variable 2    | Correlation Coefficient    |")
    print("|------------------|------------------|----------------------------|")
    
    i=0
    pairs=set()
    result = pd.DataFrame()
    for index, value in so.sort_values(ascending=False).items():        #iteritems():
        # Exclude duplicates and self-correlations
        if value > threshold \
        and index[0] != index[1] \
        and (index[0], index[1]) not in pairs \
        and (index[1], index[0]) not in pairs:
            
            print(f'|    {index[0]}    |    {index[1]}    |    {orig_corr.loc[(index[0], index[1])]}    |')
            result.loc[i, ['Variable 1', 'Variable 2', 'Correlation Coefficient']] = [index[0], index[1], orig_corr.loc[(index[0], index[1])]]
            pairs.add((index[0], index[1]))
            i+=1
    return result.reset_index(drop=True).set_index(['Variable 1', 'Variable 2'])

# %%
get_top_correlations_blog(data_copy)
# Out:
# |    Variable 1    |    Variable 2    | Correlation Coefficient    |
# |------------------|------------------|----------------------------|
# |    temp    |    dew    |    0.8715360995666404    |
# |    weather_score_daytime    |    weather_score    |    0.8358062353774364    |
# |    weekday    |    day_of_week    |    -0.7861495404789236    |
# |    temp    |    summertime    |    0.7076370409558344    |
# |    weather_score    |    temp    |    0.7025991339937356    |
# |    dew    |    summertime    |    0.6459442194399784    |
# |    humidity    |    weather_score    |    -0.6436883542888202    |
# |    weather_score_daytime    |    daytime    |    0.6160513921498998    |
# |    humidity    |    weather_score_daytime    |    -0.5951478299737353    |
# |    increase_stock    |    weather_score_daytime    |    0.5795211190154589    |
# |    rushhour    |    weather_score_daytime    |    0.5496502158118669    |
# |    weather_score_daytime    |    temp    |    0.5030758297391703    |
# |    dew    |    humidity    |    0.48958994574346787    |
# |    rushhour    |    increase_stock    |    0.4821369383923177    |
# |    weather_score    |    increase_stock    |    0.47962106792142684    |
# |    rushhour    |    daytime    |    0.46604406046820673    |
# |    visibility    |    precip    |    -0.4550578146517802    |
# |    summertime    |    weather_score    |    0.45046353873431044    |
# |    rushhour    |    weather_score    |    0.41967268797075374    |
# |    daytime    |    increase_stock    |    0.41284101662367856    |
# |    rushhour    |    hour_of_day    |    0.4024821109761797    |
# C:\Users\Ellaa\AppData\Local\Temp\ipykernel_20404\3136200794.py:25: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'temp' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   result.loc[i, ['Variable 1', 'Variable 2', 'Correlation Coefficient']] = [index[0], index[1], orig_corr.loc[(index[0], index[1])]]
# C:\Users\Ellaa\AppData\Local\Temp\ipykernel_20404\3136200794.py:25: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'dew' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   result.loc[i, ['Variable 1', 'Variable 2', 'Correlation Coefficient']] = [index[0], index[1], orig_corr.loc[(index[0], index[1])]]
#                                              Correlation Coefficient
# Variable 1            Variable 2
# temp                  dew                                   0.871536
# weather_score_daytime weather_score                         0.835806
# weekday               day_of_week                          -0.786150
# temp                  summertime                            0.707637
# weather_score         temp                                  0.702599
# dew                   summertime                            0.645944
# humidity              weather_score                        -0.643688
# weather_score_daytime daytime                               0.616051
# humidity              weather_score_daytime                -0.595148
# increase_stock        weather_score_daytime                 0.579521
# rushhour              weather_score_daytime                 0.549650
# weather_score_daytime temp                                  0.503076
# dew                   humidity                              0.489590
# rushhour              increase_stock                        0.482137
# weather_score         increase_stock                        0.479621
# rushhour              daytime                               0.466044
# visibility            precip                               -0.455058
# summertime            weather_score                         0.450464
# rushhour              weather_score                         0.419673
# daytime               increase_stock                        0.412841
# rushhour              hour_of_day                           0.402482

# %%
data_new = data_copy.copy()
data_scaled = (data_new-data_new.mean())/data_new.std()
data_scaled.iloc[:4]
# Out:
#    hour_of_day  day_of_week     month   holiday   weekday  summertime  \
# 0    -0.916942     0.982382 -1.582970 -0.185036 -1.564208   -1.343833
# 1     1.385757     0.485602 -1.582970 -0.185036  0.638902   -1.343833
# 2     1.385757    -0.011178  0.443232 -0.185036  0.638902    0.743675
# 3    -1.492616     1.479162 -1.582970 -0.185036 -1.564208   -1.343833
#
#        temp       dew  humidity    precip  snowdepth  windspeed  cloudcover  \
# 0 -2.418870 -2.269071 -0.537115 -0.132568  -0.101407   0.414805   -0.999191
# 1 -1.782050 -2.049652 -1.203278 -0.132568  -0.101407   1.394609    0.652774
# 2  1.261733  1.401218  0.495935 -0.132568  -0.101407  -1.686617    0.512312
# 3 -1.307134 -1.171974 -0.219495 -0.132568  -0.101407   0.788678   -1.964110
#
#    visibility  increase_stock   daytime  rushhour  weather_score  \
# 0     0.28225       -0.468375 -1.091346 -0.508615      -1.746710
# 1     0.28225       -0.468375 -1.091346 -0.508615      -0.568242
# 2     0.28225       -0.468375 -1.091346 -0.508615       0.440865
# 3     0.28225       -0.468375 -1.091346 -0.508615      -1.247860
#
#    weather_score_daytime
# 0              -0.672325
# 1              -0.672325
# 2              -0.672325
# 3              -0.672325

# %%
get_top_correlations_blog(data_scaled)
# Out:
# |    Variable 1    |    Variable 2    | Correlation Coefficient    |
# |------------------|------------------|----------------------------|
# |    temp    |    dew    |    0.8715360995666401    |
# |    weather_score_daytime    |    weather_score    |    0.8358062353774351    |
# |    weekday    |    day_of_week    |    -0.7861495404789227    |
# |    temp    |    summertime    |    0.7076370409558336    |
# |    weather_score    |    temp    |    0.7025991339937353    |
# |    dew    |    summertime    |    0.6459442194399778    |
# |    humidity    |    weather_score    |    -0.643688354288821    |
# |    weather_score_daytime    |    daytime    |    0.6160513921498991    |
# |    humidity    |    weather_score_daytime    |    -0.595147829973736    |
# |    increase_stock    |    weather_score_daytime    |    0.5795211190154582    |
# |    rushhour    |    weather_score_daytime    |    0.5496502158118663    |
# |    weather_score_daytime    |    temp    |    0.503075829739171    |
# |    dew    |    humidity    |    0.48958994574346915    |
# |    rushhour    |    increase_stock    |    0.4821369383923171    |
# |    weather_score    |    increase_stock    |    0.47962106792142667    |
# |    rushhour    |    daytime    |    0.4660440604682055    |
# |    visibility    |    precip    |    -0.45505781465177914    |
# |    summertime    |    weather_score    |    0.45046353873430994    |
# |    rushhour    |    weather_score    |    0.4196726879707538    |
# |    daytime    |    increase_stock    |    0.4128410166236778    |
# |    rushhour    |    hour_of_day    |    0.40248211097617914    |
# C:\Users\Ellaa\AppData\Local\Temp\ipykernel_20404\3136200794.py:25: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'temp' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   result.loc[i, ['Variable 1', 'Variable 2', 'Correlation Coefficient']] = [index[0], index[1], orig_corr.loc[(index[0], index[1])]]
# C:\Users\Ellaa\AppData\Local\Temp\ipykernel_20404\3136200794.py:25: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'dew' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   result.loc[i, ['Variable 1', 'Variable 2', 'Correlation Coefficient']] = [index[0], index[1], orig_corr.loc[(index[0], index[1])]]
#                                              Correlation Coefficient
# Variable 1            Variable 2
# temp                  dew                                   0.871536
# weather_score_daytime weather_score                         0.835806
# weekday               day_of_week                          -0.786150
# temp                  summertime                            0.707637
# weather_score         temp                                  0.702599
# dew                   summertime                            0.645944
# humidity              weather_score                        -0.643688
# weather_score_daytime daytime                               0.616051
# humidity              weather_score_daytime                -0.595148
# increase_stock        weather_score_daytime                 0.579521
# rushhour              weather_score_daytime                 0.549650
# weather_score_daytime temp                                  0.503076
# dew                   humidity                              0.489590
# rushhour              increase_stock                        0.482137
# weather_score         increase_stock                        0.479621
# rushhour              daytime                               0.466044
# visibility            precip                               -0.455058
# summertime            weather_score                         0.450464
# rushhour              weather_score                         0.419673
# daytime               increase_stock                        0.412841
# rushhour              hour_of_day                           0.402482

# %%
sns.scatterplot(data=data,x="dew",y="temp", hue= "increase_stock",style = "summertime") # hue = "increase_stock")
#sns.scatterplot(data=data[data["summertime"] == 0],x="dew",y="temp",hue = "increase_stock")
# Out:
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='dew', ylabel='temp'>

# %%
data_scaled["summertime"]
# Out:
# 0      -1.343833
# 1      -1.343833
# 2       0.743675
# 3      -1.343833
# 4      -1.343833
#           ...
# 1595    0.743675
# 1596    0.743675
# 1597    0.743675
# 1598    0.743675
# 1599   -1.343833
# Name: summertime, Length: 1600, dtype: float64

# %%
sns.countplot(data=data[data["precip"]!=0],x = "precip",hue = "increase_stock")
# Out:
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='precip', ylabel='count'>

# %%
sns.countplot(data=data[data["snowdepth"]!=0],x = "snowdepth",hue = "increase_stock")
# Out:
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='snowdepth', ylabel='count'>

# %%
sns.scatterplot(data=data_new,x="humidity",y="temp", hue= "increase_stock") # hue = "increase_stock")
# Out:
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='humidity', ylabel='temp'>

# %%
data[data["snowdepth"]!= 0].count()[0]
# Out:
# C:\Users\Ellaa\AppData\Local\Temp\ipykernel_20404\3051955464.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   data[data["snowdepth"]!= 0].count()[0]
# 58

# %%
data[data["snow"]!= 0].count()[0]
# Out:
# C:\Users\Ellaa\AppData\Local\Temp\ipykernel_20404\3705741435.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   data[data["snow"]!= 0].count()[0]
# 0

# %%
data[data["precip"]!= 0].count()[0]
# Out:
# C:\Users\Ellaa\AppData\Local\Temp\ipykernel_20404\528393817.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   data[data["precip"]!= 0].count()[0]
# 155

# %%
#visualize the distributions for across summertime (since it is binary)
data_violin = data[['increase_stock','temp','humidity','hour_of_day','summertime','month', 'weekday']]
sns.violinplot(data=data_violin,x='increase_stock',y='temp',palette='viridis')
# Out:
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='increase_stock', ylabel='temp'>

# %%
sns.violinplot(data=data_violin,x='increase_stock',y='temp', hue='weekday', palette='viridis', linewidth=.8)
# Out:
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='increase_stock', ylabel='temp'>

# %%
plt.figure(figsize=(16,4))
sns.violinplot(data=data_violin,x='month',y='temp', hue='increase_stock', palette='viridis', linewidth=.3)
# Out:
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='month', ylabel='temp'>

# %%
plt.figure(figsize=(16,2))
sns.violinplot(data=data_violin,x='hour_of_day',y='temp', hue='increase_stock', palette='viridis', linewidth=.2)
# Out:
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Ellaa\anaconda3\envs\ds\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='hour_of_day', ylabel='temp'>

# %%
data_copy['weather_score'].describe()
# Out:
# count    1600.000000
# mean        0.180000
# std         0.184322
# min        -0.239787
# 25%         0.049945
# 50%         0.154343
# 75%         0.278779
# max         0.956538
# Name: weather_score, dtype: float64
